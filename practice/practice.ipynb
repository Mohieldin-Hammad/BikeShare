# %%
import pandas as pd

# %%
data = pd.read_csv("mini_chicago.csv")

# %%
data.head()
# Out:
#         Start Time         End Time  Trip Duration  \
# 0  5/29/2017 18:36  5/29/2017 18:49            780
# 1  6/12/2017 19:00  6/12/2017 19:24           1429
# 2  2/13/2017 17:02  2/13/2017 17:20           1088
# 3  4/24/2017 18:39  4/24/2017 18:54            914
# 4  1/26/2017 15:36  1/26/2017 15:43            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year
# 0  Subscriber    Male      1991.0
# 1    Customer     NaN         NaN
# 2  Subscriber  Female      1982.0
# 3  Subscriber    Male      1966.0
# 4  Subscriber  Female      1983.0

# %%
data.columns
# Out:
# Index(['Start Time', 'End Time', 'Trip Duration', 'Start Station',
#        'End Station', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')

# %%
data.values
# Out:
# array([['5/29/2017 18:36', '5/29/2017 18:49', 780, ..., 'Subscriber',
#         'Male', 1991.0],
#        ['6/12/2017 19:00', '6/12/2017 19:24', 1429, ..., 'Customer', nan,
#         nan],
#        ['2/13/2017 17:02', '2/13/2017 17:20', 1088, ..., 'Subscriber',
#         'Female', 1982.0],
#        ...,
#        ['6/9/2017 17:03', '6/9/2017 17:24', 1246, ..., 'Customer', nan,
#         nan],
#        ['5/16/2017 8:14', '5/16/2017 8:28', 837, ..., 'Subscriber',
#         'Male', 1988.0],
#        ['5/16/2017 12:48', '5/16/2017 12:58', 583, ..., 'Subscriber',
#         'Male', 1990.0]], dtype=object)

# %%
data.tail()
# Out:
#           Start Time         End Time  Trip Duration  \
# 395   2/6/2017 13:34   2/6/2017 13:41            423
# 396  5/22/2017 16:44  5/22/2017 16:48            237
# 397   6/9/2017 17:03   6/9/2017 17:24           1246
# 398   5/16/2017 8:14   5/16/2017 8:28            837
# 399  5/16/2017 12:48  5/16/2017 12:58            583
#
#                   Start Station                        End Station  \
# 395    Jefferson St & Monroe St           Racine Ave & Randolph St
# 396      Clark St & Randolph St       Clinton St & Washington Blvd
# 397     Streeter Dr & Grand Ave             Michigan Ave & Lake St
# 398        Wabash Ave & 16th St                 Daley Center Plaza
# 399  Larrabee St & Kingsbury St  Sangamon St & Washington Blvd (*)
#
#       User Type Gender  Birth Year
# 395  Subscriber   Male      1973.0
# 396  Subscriber   Male      1959.0
# 397    Customer    NaN         NaN
# 398  Subscriber   Male      1988.0
# 399  Subscriber   Male      1990.0

# %%
data.describe()
# Out:
#        Trip Duration   Birth Year
# count     400.000000   330.000000
# mean      938.215000  1980.533333
# std      2466.972184    11.723011
# min        97.000000  1949.000000
# 25%       407.000000  1973.000000
# 50%       634.000000  1984.000000
# 75%       997.750000  1989.000000
# max     47551.000000  1999.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Start Time     400 non-null    object
#  1   End Time       400 non-null    object
#  2   Trip Duration  400 non-null    int64
#  3   Start Station  400 non-null    object
#  4   End Station    400 non-null    object
#  5   User Type      400 non-null    object
#  6   Gender         330 non-null    object
#  7   Birth Year     330 non-null    float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 25.1+ KB

# %%
data["Birth Year"].value_counts().head(1)
# Out:
# 1989.0    24
# Name: Birth Year, dtype: int64

# %%
import numpy as np

# %%
data["Trip Duration"].unique()
# Out:
# array([  780,  1429,  1088,   914,   434,  1057,   316,   559,  2517,
#          379,   333,   197,   302,   191,   489,   811,   439,   459,
#         1873,   578,   816,  1045,  1060,   359,   873,   314,  1422,
#          905,   844,   237,   889,   354,   187,  5216,   419,   169,
#         1317,   258,  1166,   247,   848,   888,   819,   552,  1446,
#          717,   272,   476,   834,   912,   951,   852,  1041,   500,
#          804,   591,   879,   244,   113,  2571,  1270,   787,  1883,
#          828,   721,   396,   813,   468,   332,   992,  1012,   506,
#          221,   255,  1072,   527,  1463,   452,   262,   340,   681,
#          969,   660,   694,  1412,   667,   515,   542,   635,   563,
#         2808,   538,   926,  1951,   679,  1414,   292,  1852,   269,
#          296,   827,  4753,   596,   472,   311,  1539,   411,   124,
#          227,   997,  1295,  1394,  1000,   373,   972,  1571,  1142,
# ...

# %%
data.isnull().sum()
# Out:
# Start Time        0
# End Time          0
# Trip Duration     0
# Start Station     0
# End Station       0
# User Type         0
# Gender           70
# Birth Year       70
# dtype: int64

# %%
data[["Gender", "Birth Year"]].isnull().value_counts()
# Out:
# Gender  Birth Year
# False   False         330
# True    True           70
# dtype: int64

# %% [markdown]
# ## Practice Solution #1: Compute the Most Popular Start Hour

# %%
data.head()
# Out:
#         Start Time         End Time  Trip Duration  \
# 0  5/29/2017 18:36  5/29/2017 18:49            780
# 1  6/12/2017 19:00  6/12/2017 19:24           1429
# 2  2/13/2017 17:02  2/13/2017 17:20           1088
# 3  4/24/2017 18:39  4/24/2017 18:54            914
# 4  1/26/2017 15:36  1/26/2017 15:43            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year
# 0  Subscriber    Male      1991.0
# 1    Customer     NaN         NaN
# 2  Subscriber  Female      1982.0
# 3  Subscriber    Male      1966.0
# 4  Subscriber  Female      1983.0

# %%
data["Start Time"] = pd.to_datetime(data["Start Time"])

# %%
data.head()
# Out:
#            Start Time         End Time  Trip Duration  \
# 0 2017-05-29 18:36:00  5/29/2017 18:49            780
# 1 2017-06-12 19:00:00  6/12/2017 19:24           1429
# 2 2017-02-13 17:02:00  2/13/2017 17:20           1088
# 3 2017-04-24 18:39:00  4/24/2017 18:54            914
# 4 2017-01-26 15:36:00  1/26/2017 15:43            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year
# 0  Subscriber    Male      1991.0
# 1    Customer     NaN         NaN
# 2  Subscriber  Female      1982.0
# 3  Subscriber    Male      1966.0
# 4  Subscriber  Female      1983.0

# %%
data["hours"] = data["Start Time"].dt.hour

# %%
data.head()
# Out:
#            Start Time         End Time  Trip Duration  \
# 0 2017-05-29 18:36:00  5/29/2017 18:49            780
# 1 2017-06-12 19:00:00  6/12/2017 19:24           1429
# 2 2017-02-13 17:02:00  2/13/2017 17:20           1088
# 3 2017-04-24 18:39:00  4/24/2017 18:54            914
# 4 2017-01-26 15:36:00  1/26/2017 15:43            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year  hours
# 0  Subscriber    Male      1991.0     18
# 1    Customer     NaN         NaN     19
# 2  Subscriber  Female      1982.0     17
# 3  Subscriber    Male      1966.0     18
# ...

# %%
popular_hour = data["hours"].mode()[0]

# %%
print("most repeated start hour is : ", popular_hour)
# Out:
# most repeated start hour is :  17

# %% [markdown]
# ## Practice Problem #2: Display a Breakdown of User Types

# %%
data["User Type"].value_counts()
# Out:
# Subscriber    330
# Customer       70
# Name: User Type, dtype: int64

# %% [markdown]
# ## Practice Problem #3: Load and Filter the Dataset

# %% [markdown]
#     """
#     Loads data for the specified city and filters by month and day if applicable.
#
#     Args:
#         (str) city - name of the city to analyze
#         (str) month - name of the month to filter by, or "all" to apply no month filter
#         (str) day - name of the day of week to filter by, or "all" to apply no day filter
#     Returns:
#         df - pandas DataFrame containing city data filtered by month and day
#     """

# %%
# load data file into a dataframe
df = pd.read_csv("mini_chicago.csv")

# %%
# convert the Start Time column to datetime
df['Start Time'] = pd.to_datetime(df["Start Time"])

# %%
df.head()
# Out:
#            Start Time         End Time  Trip Duration  \
# 0 2017-05-29 18:36:00  5/29/2017 18:49            780
# 1 2017-06-12 19:00:00  6/12/2017 19:24           1429
# 2 2017-02-13 17:02:00  2/13/2017 17:20           1088
# 3 2017-04-24 18:39:00  4/24/2017 18:54            914
# 4 2017-01-26 15:36:00  1/26/2017 15:43            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year
# 0  Subscriber    Male      1991.0
# 1    Customer     NaN         NaN
# 2  Subscriber  Female      1982.0
# 3  Subscriber    Male      1966.0
# 4  Subscriber  Female      1983.0

# %%
# extract month and day of week from Start Time to create new columns
df['month'] = df["Start Time"].dt.month
df.head()
# Out:
#            Start Time         End Time  Trip Duration  \
# 0 2017-05-29 18:36:00  5/29/2017 18:49            780
# 1 2017-06-12 19:00:00  6/12/2017 19:24           1429
# 2 2017-02-13 17:02:00  2/13/2017 17:20           1088
# 3 2017-04-24 18:39:00  4/24/2017 18:54            914
# 4 2017-01-26 15:36:00  1/26/2017 15:43            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year  month
# 0  Subscriber    Male      1991.0      5
# 1    Customer     NaN         NaN      6
# 2  Subscriber  Female      1982.0      2
# 3  Subscriber    Male      1966.0      4
# ...

# %%
df["day_of_week"] = df["Start Time"].dt.day_name()
df.head()
# Out:
#            Start Time         End Time  Trip Duration  \
# 0 2017-05-29 18:36:00  5/29/2017 18:49            780
# 1 2017-06-12 19:00:00  6/12/2017 19:24           1429
# 2 2017-02-13 17:02:00  2/13/2017 17:20           1088
# 3 2017-04-24 18:39:00  4/24/2017 18:54            914
# 4 2017-01-26 15:36:00  1/26/2017 15:43            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year  month day_of_week
# 0  Subscriber    Male      1991.0      5      Monday
# 1    Customer     NaN         NaN      6      Monday
# 2  Subscriber  Female      1982.0      2      Monday
# ...

# %%
# filter by month if applicable
month = "march"

if month != 'all':
    # use the index of the months list to get the corresponding int
    months = ['january', 'february', 'march', 'april', 'may', 'june']
    month = months.index(month) + 1

    # filter by month to create the new dataframe
    df = df[df["month"] == month]

# %%
df.head()
# Out:
#             Start Time         End Time  Trip Duration  \
# 7  2017-03-21 07:23:00   3/21/2017 7:33            559
# 11 2017-03-09 09:15:00    3/9/2017 9:18            197
# 12 2017-03-22 06:54:00   3/22/2017 6:59            302
# 14 2017-03-13 13:19:00  3/13/2017 13:27            489
# 31 2017-03-29 06:57:00   3/29/2017 7:03            354
#
#                   Start Station                        End Station  \
# 7           Canal St & Adams St             Michigan Ave & Lake St
# 11           Clark St & Lake St               Rush St & Hubbard St
# 12    Larrabee St & Division St                  Clark St & Elm St
# 14   LaSalle St & Washington St  Sangamon St & Washington Blvd (*)
# 31  Oakley Ave & Irving Park Rd            Talman Ave & Addison St
#
#      User Type  Gender  Birth Year  month day_of_week
# 7   Subscriber    Male      1969.0      3     Tuesday
# 11  Subscriber    Male      1986.0      3    Thursday
# 12  Subscriber  Female      1990.0      3   Wednesday
# ...

# %%
day = "friday"
# filter by day of week if applicable
if day != 'all':
    # filter by day of week to create the new dataframe
    df = df[df["day_of_week"] == day.title()]

# %%
df.head()
# Out:
#             Start Time         End Time  Trip Duration  \
# 40 2017-03-24 13:06:00  3/24/2017 13:10            247
# 59 2017-03-03 07:55:00    3/3/2017 7:57            113
# 68 2017-03-17 12:14:00  3/17/2017 12:22            468
# 75 2017-03-10 13:40:00  3/10/2017 13:45            255
# 83 2017-03-24 14:15:00  3/24/2017 14:27            681
#
#                   Start Station               End Station   User Type  Gender  \
# 40        Broadway & Berwyn Ave     Clark St & Berwyn Ave  Subscriber  Female
# 59       Clark St & Chicago Ave       Wells St & Huron St  Subscriber    Male
# 68  Dearborn Pkwy & Delaware Pl    State St & Randolph St  Subscriber  Female
# 75           Clark St & Lake St      Rush St & Hubbard St  Subscriber  Female
# 83   Sheridan Rd & Lawrence Ave  Broadway & Thorndale Ave  Subscriber    Male
#
#     Birth Year  month day_of_week
# 40      1961.0      3      Friday
# 59      1981.0      3      Friday
# 68      1984.0      3      Friday
# ...

# %%
"new york".title()
# Out:
# 'New York'

# %%
print('\nCalculating The Most Popular Stations and Trip...\n')
start_time = time.time()

# display most commonly used start station
print()

# display most commonly used end station


# display most frequent combination of start station and end station trip


print("\nThis took %s seconds." % (time.time() - start_time))

# %%
df["Start Station"].mode()
# Out:
# 0    Streeter Dr & Grand Ave
# dtype: object
